# %%
m=[]
i=2000
while(i<=3200):
    if(i%7==0 and i%5!=0):
        m.append(i)
    i=i+1
m
# Out:
# [2002,
#  2009,
#  2016,
#  2023,
#  2037,
#  2044,
#  2051,
#  2058,
#  2072,
#  2079,
#  2086,
#  2093,
#  2107,
#  2114,
#  2121,
#  2128,
#  2142,
#  2149,
#  2156,
#  2163,
#  2177,
#  2184,
#  2191,
#  2198,
#  2212,
#  2219,
#  2226,
#  2233,
#  2247,
#  2254,
#  2261,
#  2268,
#  2282,
#  2289,
#  2296,
#  2303,
#  2317,
#  2324,
#  2331,
#  2338,
#  2352,
#  2359,
#  2366,
#  2373,
#  2387,
#  2394,
#  2401,
#  2408,
#  2422,
#  2429,
#  2436,
#  2443,
#  2457,
#  2464,
#  2471,
#  2478,
#  2492,
#  2499,
#  2506,
#  2513,
#  2527,
#  2534,
#  2541,
#  2548,
#  2562,
#  2569,
#  2576,
#  2583,
#  2597,
#  2604,
#  2611,
#  2618,
#  2632,
#  2639,
#  2646,
#  2653,
#  2667,
#  2674,
#  2681,
#  2688,
#  2702,
#  2709,
#  2716,
#  2723,
#  2737,
#  2744,
#  2751,
#  2758,
#  2772,
#  2779,
#  2786,
#  2793,
#  2807,
#  2814,
#  2821,
#  2828,
#  2842,
#  2849,
#  2856,
#  2863,
#  2877,
#  2884,
#  2891,
#  2898,
#  2912,
#  2919,
#  2926,
#  2933,
#  2947,
#  2954,
#  2961,
# ...

# %%
a=input("enter first name:")
b=input("enter second name:")
print(a[::-1] , b[::-1])
# Out:
# enter first name:shreya
# enter second name:reddy
# ayerhs ydder

# %%
r=6
pi=3.14
x=(4/3)*pi*(r**1/3)
x
# Out:
# 8.373333333333333

# %%
a=int(input("enter values"))
r=[1,2,3,4,5,9,5,7,6,5,5]
m=[]
for i in r:
    if i==a:
        m.append(i)
m
# Out:
# enter values5
# [5, 5, 5, 5]

# %%
for i in range(0,5):
    for j in range(0,i+1):
        print("*",end=' ')
    print("\n")
print(" ")
    
for i in range(5,0,-1):
    for j in range(0,i+1,-1):
        print("*",end=' ')
    print("\n")
# Out:
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
